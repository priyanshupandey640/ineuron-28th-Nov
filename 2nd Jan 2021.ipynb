# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.read_csv('/Users/Priyanshu.Pandey/Downloads/Incident assigned by L1 to L2 where L2 is not part of routing rule List (1).csv')
# Out:
#          Number                                  Short description Region  \
# 0    INC2849118                                       access issue   EURO
# 1    INC2859371  pls add Martin Mager, Veronic Hauber, Monika M...   EURO
# 2    INC2859371  pls add Martin Mager, Veronic Hauber, Monika M...   EURO
# 3    INC2881746   cpu socket for mouse and keyboard is not working   AMER
# 4    INC2844455             I am unable to Access or assign access   AMEA
# ..          ...                                                ...    ...
# 299  INC2849871                                                NaN    NaN
# 300  INC2849365                                                NaN    NaN
# 301  INC2842521                                                NaN    NaN
# 302  INC2732539                                                NaN    NaN
# 303  INC2848593                                                NaN    NaN
#
#                   Closed               Opened Business service  \
# ...

# %%
df=pd.read_csv('/Users/Priyanshu.Pandey/Downloads/Incident assigned by L1 to L2 where L2 is not part of routing rule List (1).csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Number"]
# Out:
# 0      INC2849118
# 1      INC2859371
# 2      INC2859371
# 3      INC2881746
# 4      INC2844455
#           ...
# 299    INC2849871
# 300    INC2849365
# 301    INC2842521
# 302    INC2732539
# 303    INC2848593
# Name: Number, Length: 304, dtype: object

# %%
df.head(2)
# Out:
#        Number                                  Short description Region  \
# 0  INC2849118                                       access issue   EURO
# 1  INC2859371  pls add Martin Mager, Veronic Hauber, Monika M...   EURO
#
#                 Closed               Opened Business service  \
# 0  2020-10-06 10:00:01  2020-09-24 06:50:58      Amelia Chat
# 1  2020-10-14 02:00:48  2020-09-30 14:17:15   CheckPoint VPN
#
#                 Situation  Parent Incident                  Assignment group  \
# 0  My issue is not listed              NaN  HY-GLBL-Security Engineering Ops
# 1    Add users to profile              NaN  HY-GLBL-Security Engineering Ops
#
#                             Assignment Group History  Contact type  \
# 0  HY-GLBL-Service Desk Chat, IY-GLBL-Portal App ...          Chat
# 1  HY-GLBL-Service Desk Level 1, IY-GLBL-HCM, HY-...  Self-Service
#
#   Contact Sub Type                                               Type  \
# ...

# %%
df.tail(2)
# Out:
#          Number Short description Region               Closed  \
# 302  INC2732539               NaN    NaN  2020-10-01 13:00:17
# 303  INC2848593               NaN    NaN  2020-10-01 01:00:08
#
#                   Opened Business service Situation  Parent Incident  \
# 302  2020-07-19 10:46:58              NaN       NaN              NaN
# 303  2020-09-23 22:36:06              NaN       NaN              NaN
#
#                      Assignment group  \
# 302           IY-GLBL-GSS-SPS Level 2
# 303  IY-GLBL-IHG Reporting Support-T3
#
#                               Assignment Group History Contact type  \
# 302                       HY-GLBL-Service Desk Level 1          NaN
# 303  HY-GLBL-Service Desk Level 1, HY-GLBL-Service ...          NaN
#
#     Contact Sub Type                                               Type  \
# 302              NaN  Incidents assigned by L1 to L2 where L2 is not...
# 303              NaN  Incidents assigned by L1 to L2 where L2 is not...
#
# ...

# %%
df.take([3])
# Out:
#        Number                                 Short description Region  \
# 3  INC2881746  cpu socket for mouse and keyboard is not working   AMER
#
#                 Closed               Opened Business service  \
# 3  2020-10-21 14:00:01  2020-10-13 13:27:04              CPU
#
#                    Situation  Parent Incident              Assignment group  \
# 3  Device is not functioning              NaN  HY-GLBL-Service Desk Level 1
#
#                             Assignment Group History Contact type  \
# 3  HY-GLBL-Service Desk Level 1, IY-GLBL-GSS AMER...        Phone
#
#   Contact Sub Type                                               Type  \
# 3              NaN  Incidents assigned by L1 to L2 where L2 is not...
#
#                Service-Situation  Order
# 3  CPU-Device is not functioning      2

# %%
df.count()
# Out:
# Number                      304
# Short description            44
# Region                       44
# Closed                      304
# Opened                      304
# Business service             44
# Situation                    44
# Parent Incident               0
# Assignment group            304
# Assignment Group History    304
# Contact type                 44
# Contact Sub Type              7
# Type                        304
# Service-Situation           304
# Order                       304
# dtype: int64

# %%
df.keys()
# Out:
# Index(['Number', 'Short description', 'Region', 'Closed', 'Opened',
#        'Business service', 'Situation', 'Parent Incident', 'Assignment group',
#        'Assignment Group History', 'Contact type', 'Contact Sub Type', 'Type',
#        'Service-Situation', 'Order'],
#       dtype='object')

# %%
pd.read_table('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/test.tsv',header=None,names=['a','b','c','d','e'],usecols=['a','b'])
# Out:
#        a      b
# 0   test   test
# 1   sudh   sudh
# 2  kumar  kumar

# %%
ght=pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/csv_mindex.csv',index_col=['key1','key2'])

# %%
ght
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
ght.index
# Out:
# MultiIndex([('one', 'a'),
#             ('one', 'b'),
#             ('one', 'c'),
#             ('one', 'd'),
#             ('two', 'a'),
#             ('two', 'b'),
#             ('two', 'c'),
#             ('two', 'd')],
#            names=['key1', 'key2'])

# %%
import pandas as pd

# %%
pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/ex4.csv',skiprows=(0,2,3),usecols=None)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/ex5.csv',na_values='a')
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.read_excel('C:/Users/Priyanshu.Pandey/Downloads/Incident Mylearning July 2020 to September 2020.xlsx',skiprows=(0,1,2))
# Out:
#                                            Row Labels     Jul     Aug     Sep  \
# 0                Unable to access application/service   476.0   354.0   380.0
# 1                 Assigning Certificate of Completion   321.0   233.0   172.0
# 2              Application Error / Performance Issues   123.0   198.0   151.0
# 3                                         Transcripts   111.0    91.0    91.0
# 4                                        Registration    90.0    68.0   109.0
# 5                                    Launch Web-Based    91.0    96.0    71.0
# 6                                     How to/Question    73.0    50.0    54.0
# 7                                    Issue not listed    58.0    36.0    48.0
# 8                              My Team/Mgrs Dashboard    40.0    19.0    39.0
# 9                                             Billing    43.0    16.0    16.0
# 10                  Issues with Course/Class Language    29.0     9.0    20.0
# ...

# %%
import pandas as pd

# %%
dj=pd.read_html("http://www.basketball-reference.com/leagues/NBA_2015_totals.html")
dj
dj[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
dj[0].head(1)
# Out:
#   Rk      Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT% ORB  DRB  \
# 0  1  Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784  79  222
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
#
# [1 rows x 30 columns]

# %%
dj[0][['Player','Age']]
# Out:
#              Player Age
# 0        Quincy Acy  24
# 1      Jordan Adams  20
# 2      Steven Adams  21
# 3       Jeff Adrien  28
# 4     Arron Afflalo  29
# ..              ...  ..
# 670  Thaddeus Young  26
# 671  Thaddeus Young  26
# 672  Thaddeus Young  26
# 673     Cody Zeller  22
# 674    Tyler Zeller  25
#
# [675 rows x 2 columns]

# %%
import pandas as pd
titanic= pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",sep='\t')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[["Name","Age"]].head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
t=pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/ex6.csv',nrows=5)

# %%
t
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %%
## Rows and column)
t.shape
# Out:
# (5, 5)

# %%
s=pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/ex6.csv',chunksize=1000)
s

# %%
for i in s:
    print(i)
# Out:
#           one       two     three      four key
# 0    0.467976 -0.038649 -0.295344 -1.824726   L
# 1   -0.358893  1.404453  0.704965 -0.200638   B
# 2   -0.501840  0.659254 -0.421691 -0.057688   G
# 3    0.204886  1.074134  1.388361 -0.982404   R
# 4    0.354628 -0.133116  0.283763 -0.837063   Q
# ..        ...       ...       ...       ...  ..
# 995  2.311896 -0.417070 -1.409599 -0.515821   M
# 996 -0.479893 -0.650419  0.745152 -0.646038   H
# 997  0.523331  0.787112  0.486066  1.093156   D
# 998 -0.362559  0.598894 -1.843201  0.887292   W
# 999 -0.096376 -1.012999 -0.657431 -0.573315   K
#
# [1000 rows x 5 columns]
#            one       two     three      four key
# 1000  0.467976 -0.038649 -0.295344 -1.824726   T
# 1001 -0.358893  1.404453  0.704965 -0.200638   J
# 1002 -0.501840  0.659254 -0.421691 -0.057688   R
# 1003  0.204886  1.074134  1.388361 -0.982404   S
# 1004  0.354628 -0.133116  0.283763 -0.837063   B
# ...        ...       ...       ...       ...  ..
# ...

# %%
type(s)
# Out:
# pandas.io.parsers.TextFileReader

# %%
s.read()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-50-a1015ff50f2b> in <module>
# ----> 1 s.read()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# StopIteration:

# %%
data=pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/ex5.csv')
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
## to convert into other CSV file or any other file, we can change speratpr
data.to_json('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/out.jason')

# %%
data.to_json('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/out.jason')

# %%
##sys- sytem property
##sys.stdout(similar to the file with sepeartor)

# %%
import sys
data.to_csv(sys.stdout,na_rep="NULL")
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout)
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,
# 1,two,5,6,,8,world
# 2,three,9,10,11.0,12,foo

# %%
data.to_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/out2.csv',index=False, columns=['a','b','c'])

# %%
dates = pd.date_range(start=1/1/2002,end=2/1/2003)

# %%
dates
# Out:
# DatetimeIndex(['1970-01-01'], dtype='datetime64[ns]', freq='D')

# %%
len(dj)
# Out:
# 1

# %%
pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/ex4.csv',skiprows=(0,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-59bc500be275> in <module>
# ----> 1 pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/ex4.csv',skiprows=(0,1))
#
# NameError: name 'pd' is not defined

# %%
ak=pd.read_csv('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/test.tsv',sep="\t")

# %%
ak
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
pd.read_html('C:/Users/Priyanshu.Pandey/Downloads/code_pandas1/examples/fdic_failed_bank_list.html')
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
# ...

# %%
ak
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar
